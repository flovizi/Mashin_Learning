# %% [markdown]
# #### Домашнее задание «Деревья решений»
#
# Для выполнения домашнего задания необходимо взять файл boston house-prices datase (sklearn.datasets.load_boston) и построить модель.
# По аналогии задания к лекции «Классификация: Логистическая регрессия и SVM».
# А именно построить модель регрессии, дерево решений, оптимизировать параметры и сравнить результаты.

# %%
pip install six
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn==0.20.3
# Out:
# ...
#   Using cached scikit-learn-0.20.3.tar.gz (11.8 MB)
# ...
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.1
#     Uninstalling scikit-learn-0.23.1:
#       Successfully uninstalled scikit-learn-0.23.1
#     Running setup.py install for scikit-learn: started
#     Running setup.py install for scikit-learn: finished with status 'error'
#   Rolling back uninstall of scikit-learn
#   Moving to c:\programdata\anaconda3\lib\site-packages\scikit_learn-0.23.1.dist-info\
#    from C:\ProgramData\Anaconda3\Lib\site-packages\~cikit_learn-0.23.1.dist-info
#   Moving to c:\programdata\anaconda3\lib\site-packages\sklearn\
#    from C:\ProgramData\Anaconda3\Lib\site-packages\~klearn
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
pip install graphviz
# Out:
#
#     blis_info:
#       libraries blis not found in ['C:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'C:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['C:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'C:\\ProgramData\\Anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
# ...

# %%
conda install graphviz
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install python-graphviz
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score

# для отрисовки дерева
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %matplotlib inline

# увеличим размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
from sklearn.datasets import load_boston 
data = pd.DataFrame(load_boston().data, columns=load_boston().feature_names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data['target'] = load_boston().target
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# Все признаки boston являются числами (float64), категориальных данных нет, пропусков нет

# %%
# Проверим нормальное распределение целевой переменной
from scipy.stats import norm

sns.distplot(data['target'], fit=norm, kde=True, color='g')
plt.grid()

# %% [markdown]
# Будем считать распределение y, близкое к нормальному

# %%
# boxplot

sns.boxplot(data=data)

# %%
# прологарифмируем признаки с большими выбросами, хвостами и широким диапазоном значений: 'CRIM', 'ZN', 'B'

data['CRIM'] = np.log(data['CRIM'] + 1).to_numpy()
data['ZN'] = np.log(data['ZN'] + 1).to_numpy()
data['B'] = np.log(data['B'] + 1).to_numpy()

# %%
# boxplot после логарифмирования

sns.boxplot(data=data)

# %% [markdown]
# Масштаб синхронизируем при стандартизации

# %%
# уберем выбросы в 'LSTAT'
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.813418    0.953873   11.136779    0.069170    0.554695    6.284634
# std      1.022731    1.620831    6.860353    0.253994    0.115878    0.702617
# min      0.006300    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.078853    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.228336    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      1.542674    2.602690   18.100000    0.000000    0.624000    6.623500
# max      4.499545    4.615121   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534    5.759511
# ...

# %%
# возьмем 'LSTAT' < 20

data = data.loc[data.LSTAT <20]

# %%
X = data.drop(['target'], axis=1)
X
# Out:
#          CRIM        ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.006300  2.944439   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.026944  0.000000   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.026924  0.000000   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.031857  0.000000   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.066770  0.000000   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...       ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.060747  0.000000  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.044275  0.000000  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.058986  0.000000  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.103991  0.000000  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.046320  0.000000  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO         B  LSTAT
# ...

# %%
y = data.target
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, Length: 432, dtype: float64

# %% [markdown]
# #### Построим модель на основе линейной регрессии LinearRegression

# %%
class prediction:
    
    def _init_(self):
        self= self
        
    def get_score(self, X, y, pipe_model=None, random_seed=42):
        self.X = X
        self.y = y
        self.pipe_model = pipe_model
        if self.pipe_model is None:
            self.pipe_model = make_pipeline(StandardScaler(),LinearRegression())
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size=0.3, random_state=random_seed )
        self.X_test = X_test
        self.y_test = y_test
        self.X_train = X_train
        self.y_train = y_train
        self.pipe_model.fit(X_train, y_train)
        return self.pipe_model.score(X_test, y_test)
    
    def cross(self):
        kf = KFold(n_splits=10)
        scores = cross_val_score(self.pipe_model, self.X_train, self.y_train, cv=kf)
        return scores.mean(), scores

    def plot(self):
        plt.figure(figsize=(5,4))
        predictions = self.pipe_model.predict(self.X_test)
        sns.set_style('dark')
        plot = sns.scatterplot(self.y_test, predictions)
        plot.set(xlabel='Given', ylabel='Prediction')
        x_plot = np.linspace(-5,50,100)
        y_plot = x_plot
        plt.plot(x_plot, y_plot, color='r')
        plt.grid()
        plt.show()

# %%
p = prediction()

print('model.score = ', p.get_score(X=X, y=y))  
print('cross_val_score: ', p.cross())
p.plot()
# Out:
# model.score =  0.7504353242278075
# cross_val_score:  (0.6313984234169174, array([0.13308863, 0.63629418, 0.83067851, 0.82114501, 0.62598309,
#        0.82873488, 0.74604722, 0.7260108 , 0.37697531, 0.5890266 ]))

# %% [markdown]
# #### Построим модель на основе регрессора дерева решений DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Поскольку для деревьев не страшны выбросы, пропуски, разный масштаб - подготавливать данные нет необходимости

# %%
X_tree = pd.DataFrame(load_boston().data, columns=load_boston().feature_names)
X_tree.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y_tree = pd.Series(load_boston().target)
y_tree
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Length: 506, dtype: float64

# %%
class prediction_tree:
    
    def _init_(self):
        self= self
        
    def get_score(self, X, y, clf=DecisionTreeRegressor(random_state=42), random_seed=42):
        self.X = X
        self.y = y
        self.clf = clf
        
        grid_params = {
        #'criterion': ['gini', 'entropy'],  # функция измерения качества разделения
        'max_depth': np.arange(1, 11)         # максимальная глубина дерева
}
        
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size=0.3, random_state=random_seed )
        self.X_test = X_test
        self.y_test = y_test
        self.X_train = X_train
        self.y_train = y_train
        
        grid = GridSearchCV(self.clf, param_grid=grid_params, cv=10, n_jobs=-1)
        # grid - исчерпывающий поиск по заданным значениям параметров
        # n_jobs - количество заданий для параллельного выполнения
        # cv - количество фолдов
        # scoring - оценка найденных параметров
        self.grid = grid
        
        self.grid.fit(X_train, y_train)
        return self.grid.score(X_test, y_test)
    
    def best_score(self):
        return self.grid.best_score_

    def best_estimator(self):
        return self.grid.best_estimator_
    
    def best_params(self):
        return self.grid.best_params_
    
    def feature_importances(self):
        fich = self.grid.best_estimator_.feature_importances_
        plt.barh(np.arange(len(fich)), fich)
        plt.yticks(np.arange(len(self.X.columns)), self.X.columns)
        ''
        
    def plot(self):
        plt.figure(figsize=(5,4))
        predictions = self.grid.predict(self.X_test)
        sns.set_style('dark')
        plt.plot(self.X_test, self.y_test, "b")
        #plt.scatter(self.X_train, self.y_train, c="b", s=20)  # так ошибка
        plt.plot(self.X_test, predictions, "g", lw=2)
        plt.xlim([0, 1])
        plt.title("Decision tree regressor, MSE = %.2f" % np.sum((self.y_test - predictions) ** 2))
        plt.show()
        
    #def tree(self):      # выдает ошибку
        #dot_data = StringIO()
        #export_graphviz(self.grid.best_estimator_, out_file=dot_data,  
                        #filled=True, rounded=True,
                        #special_characters=True)
        #graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
        #Image(graph.create_png())                                       
        
       
        # или
        #export_graphviz(self.grid.best_estimator_, out_file='telecom_tree',  
                        #feature_names=self.X.columns,
                        #filled=True)
        #!ls -1 *.dot
        #!ls -1 *.png
        #!dot -Tpng telecom_tree.dot -o telecom_tree.png
        #<img src='telecom_tree.png'>

# %%
pt = prediction_tree()

print('model.score = ', pt.get_score(X=X_tree, y=y_tree))  
print('best_score: ', pt.best_score())
print('best_estimator: ', pt.best_estimator())
print('best_params: ', pt.best_params())
pt.feature_importances()
pt.plot()
#pt.tree()
# Out:
# model.score =  0.8507359013244257
# best_score:  0.710343168997486
# best_estimator:  DecisionTreeRegressor(max_depth=5, random_state=42)
# best_params:  {'max_depth': 5}

# %% [markdown]
# Кажется, дерево лучше справилось с задачей и без предварительной подготовки данных
